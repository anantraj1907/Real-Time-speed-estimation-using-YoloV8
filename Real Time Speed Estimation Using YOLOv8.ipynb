# %%
import cv2
import pandas as pd
from ultralytics import YOLO
import time


model = YOLO('yolov8s.pt')


def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)


cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)


cap = cv2.VideoCapture('traffic1.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")
print(class_list)

count = 0
vh_down = {}
counter = []
vh_up = {}
counter1 = []
vh_dtime = {}
vh_utime = {}
cy1 = 322
cy2 = 368
offset = 6

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (1020, 500))

def display_speed(frame, cx, cy, vehicle_id, counter_list, elapsed_time, x, y):
    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
    cv2.putText(frame, str(vehicle_id), (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    if vehicle_id not in counter_list:
        counter_list.append(vehicle_id)

    distance = 10

    if elapsed_time > 0:
        speed_ms = distance / elapsed_time
        speed_km = speed_ms * 3.6
        cv2.putText(frame, str(int(speed_km)) + ' Km/h', (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)
    else:
        cv2.putText(frame, 'Speed N/A', (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

def simple_tracker(detected_objects, tracked_objects):
    updated_tracked_objects = {}
    for i, obj in enumerate(detected_objects):
        updated_tracked_objects[i] = obj  # Assign ID based on index
    return updated_tracked_objects

while True:
    ret, frame = cap.read()
    if not ret:
        break

    count += 1
    if count % 3 != 0:
        continue

    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")

    detected_objects = []

    for index, row in px.iterrows():
        x1, y1, x2, y2, _, d = map(int, row)
        c = class_list[d]

        if c in ['car', 'truck', 'bus']:
            detected_objects.append([x1, y1, x2, y2])

    
    tracked_objects = simple_tracker(detected_objects, detected_objects)

    for id, bbox in tracked_objects.items():
        x3, y3, x4, y4 = bbox
        cx = (x3 + x4) // 2
        cy = (y3 + y4) // 2

        if cy1 - offset < cy < cy1 + offset:
            vh_down[id] = cy
            vh_dtime[id] = time.time()

        if cy2 - offset < cy < cy2 + offset:
            vh_up[id] = cy
            vh_utime[id] = time.time()

        cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 1)

        if id in vh_down:
            elapsed_time = time.time() - vh_dtime[id]
            display_speed(frame, cx, cy, id, counter, elapsed_time, x4, y4)

        if id in vh_up:
            elapsed_time2 = time.time() - vh_utime[id]
            display_speed(frame, cx, cy, id, counter1, elapsed_time2, x4, y4)

    
    cv2.line(frame, (267, cy1), (829, cy1), (255, 255, 255), 1)
    cv2.putText(frame, '1line', (274, 318), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    cv2.line(frame, (167, cy2), (932, cy2), (255, 255, 255), 1)
    cv2.putText(frame, '2line', (181, 363), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    out.write(frame)

    cv2.imshow("RGB", frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']
#
# 0: 320x640 3 cars, 309.7ms
# Speed: 23.0ms preprocess, 309.7ms inference, 17.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 179.0ms
# Speed: 4.2ms preprocess, 179.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 172.1ms
# Speed: 7.7ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck, 175.9ms
# Speed: 0.0ms preprocess, 175.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 190.6ms
# Speed: 0.0ms preprocess, 190.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 truck,
5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 1 truck, 205.3ms
# Speed: 0.0ms preprocess, 205.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 2 trucks, 202.7ms
# Speed: 0.0ms preprocess, 202.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 203.5ms
# Speed: 0.0ms preprocess, 203.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 191.7ms
# Speed: 15.6ms preprocess, 191.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 195.7ms
# Speed: 15.7ms preprocess, 195.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 4 trucks, 188.4ms
# Speed: 10.5ms preprocess, 188.4ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 200.6ms
# Speed: 0.0ms preprocess, 200.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 217.7ms
# Speed: 3.1ms preprocess, 217.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 205.5ms
# Speed: 0.0ms preprocess, 205.5ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 1 bus, 1 train, 2 trucks, 198.4ms
# Speed: 0.0ms preprocess, 198.4ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 2 trucks, 198.2ms
# Speed: 0.0ms preprocess, 198.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 188.9ms
# Speed: 15.6ms preprocess, 188.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 188.2ms
# Speed: 0.0ms preprocess, 188.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 cars, 3 trucks, 226.3ms
# Speed: 11.0ms preprocess, 226.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 3 trucks, 211.9ms
# Speed: 3.8ms preprocess, 211.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 cars, 4 trucks, 185.2ms
# Speed: 2.0ms preprocess, 185.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 200.3ms
# Speed: 0.0ms preprocess, 200.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 3 trucks, 173.4ms
# Speed: 0.0ms preprocess, 173.4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 4 trucks, 190.2ms
# Speed: 0.0ms preprocess, 190.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 2 trucks, 250.3ms
# Speed: 0.0ms preprocess, 250.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 3 trucks, 203.6ms
# Speed: 0.0ms preprocess, 203.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 204.1ms
# Speed: 0.0ms preprocess, 204.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 184.2ms
# Speed: 0.0ms preprocess, 184.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 188.1ms
# Speed: 0.0ms preprocess, 188.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 241.7ms
# Speed: 0.0ms preprocess, 241.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 203.3ms
# Speed: 1.1ms preprocess, 203.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 226.1ms
# Speed: 0.0ms preprocess, 226.1ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 203.6ms
# Speed: 0.0ms preprocess, 203.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 190.5ms
# Speed: 14.5ms preprocess, 190.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 188.4ms
# Speed: 14.0ms preprocess, 188.4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 truck, 193.1ms
# Speed: 0.0ms preprocess, 193.1ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 190.3ms
# Speed: 2.9ms preprocess, 190.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 191.8ms
# Speed: 0.0ms preprocess, 191.8ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 227.4ms
# Speed: 0.0ms preprocess, 227.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 192.7ms
# Speed: 0.0ms preprocess, 192.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 203.3ms
# Speed: 0.0ms preprocess, 203.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 204.6ms
# Speed: 15.6ms preprocess, 204.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 191.6ms
# Speed: 10.0ms preprocess, 191.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 truck, 221.3ms
# Speed: 4.5ms preprocess, 221.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 cars, 1 truck, 198.5ms
# Speed: 15.6ms preprocess, 198.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 2 trucks, 199.9ms
# Speed: 5.1ms preprocess, 199.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 201.2ms
# Speed: 0.0ms preprocess, 201.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 200.9ms
# Speed: 0.0ms preprocess, 200.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 2 trucks, 195.1ms
# Speed: 9.7ms preprocess, 195.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 bus, 2 trucks, 231.5ms
# Speed: 6.8ms preprocess, 231.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 4 trucks, 225.5ms
# Speed: 0.0ms preprocess, 225.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 bus, 3 trucks, 232.4ms
# Speed: 0.0ms preprocess, 232.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 cars, 1 bus, 4 trucks, 231.9ms
# Speed: 4.6ms preprocess, 231.9ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 bus, 1 truck, 284.9ms
# Speed: 7.9ms preprocess, 284.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 5 cars, 1 bus, 1 truck, 207.4ms
# Speed: 5.0ms preprocess, 207.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 6 cars, 1 bus, 2 trucks, 584.7ms
# Speed: 3.0ms preprocess, 584.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 4 cars, 1 bus, 1 truck, 263.4ms
# Speed: 5.1ms preprocess, 263.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
